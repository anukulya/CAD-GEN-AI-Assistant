# %%
a = ['kjs']
if a:
    b = "bbbbbbbb"

print(b)
# Out:
# bbbbbbbb

# %%
a = "" 
for i in a:
    print(i)

# %%
print(deb3['user question'])
from debris import deb3
print(deb3['message'])
# Out:
# Give me the name of faces of counter bore features
# To identify the names of the faces associated with the counterbore feature, we will analyze the relevant details typically found in a CAD model. Below is a structured response based on the common attributes of counterbore features:
#
# ### Counterbore Feature Face Identification
#
# 1. **Counterbore Feature**
#    - **Feature Name**: Counterbored Hole
#    - **Diameter**: 25.0 mm
#    - **Depth**: 50.0 mm
#    - **Direction**: FaceNormal
#    - **Origin**: (-0.28, 1.97, 64.0)
#
# 2. **Associated Faces**:
#    - **Face 1**: Top Face
#      - **Description**: The flat surface at the top of the counterbore.
#      - **Orientation**: Typically parallel to the reference plane from which the hole is created.
#    - **Face 2**: Counterbore Bottom Face
#      - **Description**: The flat surface at the bottom of the counterbore hole.
#      - **Orientation**: Perpendicular to the axis of the hole.
#    - **Face 3**: Side Face
# ...

# %%
from debris import deb1
print(deb1['message'])
# Out:
# Here is a structured analysis of the provided files, detailing their contents in a hierarchical format.
#
# ### 1. JSON File Analysis (Shopping List)
# #### 1.1 Structure Overview
# - **Root Element**: `shoppingList`
#   - Contains three main categories: `groceries`, `personalCare`, and `householdItems`.
#
# #### 1.2 Categories
# 1. **Groceries**
#    - **Items**:
#      - Apples:
#        - Quantity: 3
#        - Unit: lbs
#      - Grapes:
#        - Quantity: 2
#        - Unit: lbs
#      - Bread:
#        - Quantity: 2
#        - Unit: loaves
#      - Milk:
#        - Quantity: 1
#        - Unit: gallon
#      - Eggs:
#        - Quantity: 1
#        - Unit: dozen
#      - Chicken:
#        - Quantity: 2
#        - Unit: lbs
#      - Meat:
#        - Quantity: 1
#        - Unit: lbs
#      - Tomato:
#        - Quantity: 2
#        - Unit: lbs
#
# 2. **Personal Care**
#    - **Items**:
#      - Toothpaste:
#        - Quantity: 2
#        - Unit: packs
#      - Shampoo:
# ...

# %%
from langchain_core.messages import AIMessage

res1 = AIMessage(content='```xml\n<response>\n    <capabilities>\n        <capability>Image-Based Model Analysis</capability>\n        <capability>CAD Consultation</capability>\n    </capabilities>\n    <technicalKnowledgeBase>\n        <knowledge>Geometric Modeling</knowledge>\n        <knowledge>Engineering Principles</knowledge>\n        <knowledge>Common CAD Software</knowledge>\n        <knowledge>Computer Vision for CAD</knowledge>\n    </technicalKnowledgeBase>\n    <responseStructure>\n        <structure>Main steps (numbered 1, 2, 3...)</structure>\n        <structure>Sub-steps (numbered 1.1, 1.2, 1.3...)</structure>\n        <structure>Detailed actions (numbered 1.1.1, 1.1.2, 1.1.3...)</structure>\n        <structure>Parameters and specific values indented under their respective steps</structure>\n    </responseStructure>\n    <instructionRequirements>\n        <requirement>Setup Phase</requirement>\n        <requirement>Base Feature Creation</requirement>\n        <requirement>Feature Development</requirement>\n        <requirement>Pattern/Array Features</requirement>\n        <requirement>Fillets, Chamfers, and Finishing Features</requirement>\n        <requirement>Assembly Instructions (when applicable)</requirement>\n    </instructionRequirements>\n    <communicationStyle>\n        <style>Professional, technical tone appropriate for engineering contexts</style>\n        <style>Precise language using proper CAD and engineering terminology</style>\n    </communicationStyle>\n    <limitations>\n        <limitation>Potential inaccuracies in dimension estimation from images without proper scale references</limitation>\n        <limitation>Provide guidance based on general standards for proprietary features</limitation>\n    </limitations>\n</response>\n```', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 382, 'prompt_tokens': 926, 'total_tokens': 1308, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_7a53abb7a2', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='run-818e7f5e-2175-4e0f-a4cd-8aab2634ca78-0', usage_metadata={'input_tokens': 926, 'output_tokens': 382, 'total_tokens': 1308, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
print(res1.content)
# Out:
# ```xml
# <response>
#     <capabilities>
#         <capability>Image-Based Model Analysis</capability>
#         <capability>CAD Consultation</capability>
#     </capabilities>
#     <technicalKnowledgeBase>
#         <knowledge>Geometric Modeling</knowledge>
#         <knowledge>Engineering Principles</knowledge>
#         <knowledge>Common CAD Software</knowledge>
#         <knowledge>Computer Vision for CAD</knowledge>
#     </technicalKnowledgeBase>
#     <responseStructure>
#         <structure>Main steps (numbered 1, 2, 3...)</structure>
#         <structure>Sub-steps (numbered 1.1, 1.2, 1.3...)</structure>
#         <structure>Detailed actions (numbered 1.1.1, 1.1.2, 1.1.3...)</structure>
#         <structure>Parameters and specific values indented under their respective steps</structure>
#     </responseStructure>
#     <instructionRequirements>
#         <requirement>Setup Phase</requirement>
#         <requirement>Base Feature Creation</requirement>
# ...

# %%
res2 = AIMessage(content='Based on the provided JSON data, I will identify and categorize the different features present in the 3D model. The features include sketches, holes, edges, and faces. Below is a structured analysis of the identified features.\n\n### Identified Features\n\n1. **Sketches**:\n   - **1.1 Sketch 1**\n     - **Type**: Sketch\n     - **Origin**: (0.0, 0.0, 0.0)\n     - **Curves**:\n       - Line from (-53.0, 32.0, 0.0) to (61.0, 32.0, 0.0)\n       - Line from (61.0, -32.0, 0.0) to (-53.0, -32.0, 0.0)\n     - **Dimensions**: None\n\n   - **1.2 Sketch 2**\n     - **Type**: Sketch\n     - **Origin**: (61.0, 0.0, 19.0)\n     - **Curves**:\n       - Line from (-30.15, 32.0, 19.0) to (33.85, 32.0, 19.0)\n       - Line from (33.85, 32.0, 19.0) to (33.85, -32.0, 19.0)\n       - Line from (33.85, -32.0, 19.0) to (-30.15, -32.0, 19.0)\n       - Line from (-30.15, -32.0, 19.0) to (-30.15, 32.0, 19.0)\n     - **Dimensions**: None\n\n   - **1.3 Sketch 3**\n     - **Type**: Sketch\n     - **Origin**: (-30.15, 32.0, 64.0)\n     - **Curves**: None\n     - **Dimensions**:\n       - Dimension 1: 30.03 (Expression: p116)\n       - Dimension 2: 29.87 (Expression: p117)\n\n   - **1.4 Sketch 4**\n     - **Type**: Sketch\n     - **Origin**: (61.0, 0.0, 19.0)\n     - **Curves**: None\n     - **Dimensions**:\n       - Dimension 1: 1.88 (Expression: p230)\n       - Dimension 2: 3.22 (Expression: p231)\n\n   - **1.5 Sketch 5**\n     - **Type**: Sketch\n     - **Origin**: (-53.0, 0.0, 19.0)\n     - **Curves**: None\n     - **Dimensions**:\n       - Dimension 1: 5.72 (Expression: p344)\n       - Dimension 2: 1.62 (Expression: p345)\n\n2. **Holes**:\n   - **2.1 Hole 1**\n     - **Type**: Counterbored\n     - **Diameter**: 25.0 mm\n     - **Depth**: 50.0 mm\n     - **Origin**: (-0.28, 1.97, 64.0)\n\n   - **2.2 Hole 2**\n     - **Type**: Simple\n     - **Diameter**: 22.0 mm\n     - **Depth**: 50.0 mm\n     - **Origin**: (62.88, -3.22, 19.0)\n\n   - **2.3 Hole 3**\n     - **Type**: Simple\n     - **Diameter**: 22.0 mm\n     - **Depth**: 50.0 mm\n     - **Origin**: (-58.72, -1.62, 19.0)\n\n3. **Faces**:\n   - **3.1 Face 1**\n     - **Type**: Cylindrical\n     - **Name**: FACE-1\n   - **3.2 Face 2**\n     - **Type**: Cylindrical\n     - **Name**: FACE-2\n   - **3.3 Face 3**\n     - **Type**: Planar\n     - **Name**: FACE-3\n   - **3.4 Face 4**\n     - **Type**: Planar\n     - **Name**: FACE-4\n   - **3.5 Face 5**\n     - **Type**: Planar\n     - **Name**: FACE-5\n   - **3.6 Face 6**\n     - **Type**: Planar\n     - **Name**: FACE-6\n   - **3.7 Face 7**\n     - **Type**: Planar\n     - **Name**: FACE-7\n   - **3.8 Face 8**\n     - **Type**: Cylindrical\n     - **Name**: FACE-8\n   - **3.9 Face 9**\n     - **Type**: Cylindrical\n     - **Name**: FACE-9\n   - **3.10 Face 10**\n     - **Type**: Conical\n     - **Name**: FACE-10\n   - **3.11 Face 11**\n     - **Type**: Planar\n     - **Name**: FACE-11\n   - **3.12 Face 12**\n     - **Type**: Planar\n     - **Name**: FACE-12\n   - **3.13 Face 13**\n     - **Type**: Cylindrical\n     - **Name**: FACE-13\n   - **3.14 Face 14**\n     - **Type**: Cylindrical\n     - **Name**: FACE-14\n   - **3.15 Face 15**\n     - **Type**: Planar\n     - **Name**: FACE-15\n   - **3.16 Face 16**\n     - **Type**: Planar\n     - **Name**: FACE-16\n\n4. **Edges**:\n   - **4.1 Edge 1**\n     - **Name**: EDGE-1\n     - **Length**: 0.0\n     - **Vertices**: (-12.78, 1.97, 39.0) to (-12.78, 1.97, 39.0)\n   - **4.2 Edge 2**\n     - **Name**: EDGE-2\n     - **Length**: 19.0\n     - **Vertices**: (-53.0, -32.0, 19.0) to (-53.0, -32.0, 0.0)\n   - **4.3 Edge 3**\n     - **Name**: EDGE-3\n     - **Length**: 64.0\n     - **Vertices**: (-30.15, -32.0, 19.0) to (-30.15, 32.0, 19.0)\n   - **4.4 Edge 4**\n     - **Name**: EDGE-4\n     - **Length**: 27.15\n     - **Vertices**: (60.99, 32.0, 19.0) to (33.85, 32.0, 19.0)\n   - **4.5 Edge 5**\n     - **Name**: EDGE-5\n     - **Length**: 0.0\n     - **Vertices**: (-20.28, 1.97, 39.0) to (-20.28, 1.97, 39.0)\n   - **4.6 Edge 6**\n     - **Name**: EDGE-6\n     - **Length**: 0.0\n     - **Vertices**: (61.0, -32.0, 19.0) to (60.99, 32.0, 19.0)\n   - **4.7 Edge 7**\n     - **Name**: EDGE-7\n     - **Length**: 0.0\n     - **Vertices**: (-52.99, 31.99, 19.0) to (-53.0, -32.0, 19.0)\n   - **4.8 Edge 8**\n     - **Name**: EDGE-8\n     - **Length**: 27.15\n     - **Vertices**: (33.85, -32.0, 19.0) to (61.0, -32.0, 19.0)\n   - **4.9 Edge 9**\n     - **Name**: EDGE-9\n     - **Length**: 64.0\n     - **Vertices**: (-30.15, -32.0, 64.0) to (-30.15, 32.0, 64.0)\n   - **4.10 Edge 10**\n     - **Name**: EDGE-10\n     - **Length**: 0.0\n     - **Vertices**: (-69.72, -1.62, 19.0) to (-69.72, -1.62, 19.0)\n\n### Summary\nThe model contains multiple sketches, holes, faces, and edges, each with specific geometric properties. The sketches primarily consist of lines, while the holes are defined by their types and dimensions. The faces and edges provide additional structural information about the model.\n\nIf you need further analysis or specific details about any of the features, please let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2065, 'prompt_tokens': 11029, 'total_tokens': 13094, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_7a53abb7a2', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='run-b2e44fb1-82a2-4d49-8a93-cc9617a7c81e-0', usage_metadata={'input_tokens': 11029, 'output_tokens': 2065, 'total_tokens': 13094, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
print(res2.content)
# Out:
# Based on the provided JSON data, I will identify and categorize the different features present in the 3D model. The features include sketches, holes, edges, and faces. Below is a structured analysis of the identified features.
#
# ### Identified Features
#
# 1. **Sketches**:
#    - **1.1 Sketch 1**
#      - **Type**: Sketch
#      - **Origin**: (0.0, 0.0, 0.0)
#      - **Curves**:
#        - Line from (-53.0, 32.0, 0.0) to (61.0, 32.0, 0.0)
#        - Line from (61.0, -32.0, 0.0) to (-53.0, -32.0, 0.0)
#      - **Dimensions**: None
#
#    - **1.2 Sketch 2**
#      - **Type**: Sketch
#      - **Origin**: (61.0, 0.0, 19.0)
#      - **Curves**:
#        - Line from (-30.15, 32.0, 19.0) to (33.85, 32.0, 19.0)
#        - Line from (33.85, 32.0, 19.0) to (33.85, -32.0, 19.0)
#        - Line from (33.85, -32.0, 19.0) to (-30.15, -32.0, 19.0)
#        - Line from (-30.15, -32.0, 19.0) to (-30.15, 32.0, 19.0)
#      - **Dimensions**: None
#
#    - **1.3 Sketch 3**
#      - **Type**: Sketch
# ...

# %%
from debris import deb2

print(deb2['user question'])
print(deb2['message'])
# Out:
# Identify different manufacturing features for provided file
# To identify the different manufacturing features from the provided JSON file, we can categorize the features based on their types and characteristics. Below is a structured analysis of the manufacturing features extracted from the JSON data:
#
# ### 1. Sketch Features
#    - **Sketch 1**
#      - **Origin**: (0.0, 0.0, 0.0)
#      - **Curves**:
#        - Line from (-53.0, 32.0, 0.0) to (61.0, 32.0, 0.0)
#        - Line from (61.0, -32.0, 0.0) to (-53.0, -32.0, 0.0)
#      - **Dimensions**: None
#
#    - **Sketch 2**
#      - **Origin**: (61.0, 0.0, 19.0)
#      - **Curves**:
#        - Line from (-30.15, 32.0, 19.0) to (33.85, 32.0, 19.0)
#        - Line from (33.85, 32.0, 19.0) to (33.85, -32.0, 19.0)
#        - Line from (33.85, -32.0, 19.0) to (-30.15, -32.0, 19.0)
#        - Line from (-30.15, -32.0, 19.0) to (-30.15, 32.0, 19.0)
#      - **Dimensions**: None
#
#    - **Sketch 3**
# ...

# %%
from IPython.display import SVG, display
def show_svg(svg_code: str, text: str = ""):
    display(SVG(svg_code))
    if text:
        display(text)
